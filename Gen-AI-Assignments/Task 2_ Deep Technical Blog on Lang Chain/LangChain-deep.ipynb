# %% [markdown]
# # 1. Installation

# %%
# !pip install -U transformers langchain langchain-community faiss-cpu
# Out:
# Requirement already satisfied: transformers in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (5.5.4)
# Requirement already satisfied: langchain in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-community in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.4.1)
# Requirement already satisfied: faiss-cpu in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.13.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from transformers) (1.11.0)
# Requirement already satisfied: numpy>=1.17 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from transformers) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Akshat Chauhan\AppData\Roaming\Python\Python314\site-packages (from transformers) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from transformers) (2026.4.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.28.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain) (1.2.31)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain) (2.13.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.32)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.1 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-community) (1.0.4)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Requirement already satisfied: greenlet>=1 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: colorama in C:\Users\Akshat Chauhan\AppData\Roaming\Python\Python314\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer->transformers) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\Akshat Chauhan\AppData\Roaming\Python\Python314\site-packages (from rich>=12.3.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\Akshat Chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)

# %% [markdown]
# #  2. Local LLM using HuggingFace

# %%
from transformers import pipeline

# Load local model
generator = pipeline("text-generation", model="gpt2")

def llm_response(prompt):
    result = generator(prompt, max_length=100, num_return_sequences=1)
    return result[0]['generated_text']

print(llm_response("Explain LangChain in simple terms"))
# Out:
# Loading weights: 100%|██████████| 148/148 [00:00<00:00, 7614.69it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Explain LangChain in simple terms:
#
# 1. Find the top 10 percent of each of the 10 largest companies in the United States.
#
# 2. Select a company to check out:
#
# 1) Google
#
# 2) Facebook
#
# 3) Twitter
#
# 4) LinkedIn
#
# 5) Google
#
# 6) Amazon
#
# 7) Microsoft
#
# 8) eBay
#
# 9) Apple
#
# 10) Google
#
# 11) Yahoo!
#
# 12) Microsoft
#
# 13) AOL
#
# 14) IBM
#
# 15) Apple
#
# 16) Google
#
# 17) Amazon
#
# 18) Facebook
#
# 19) Yahoo!
#
# 20) Microsoft
#
# 21) Microsoft
#
# 22) IBM
#
# 23) Apple
#
# 24) Google
#
# 25) Yahoo!
#
# 26) AOL
#
# 27) Yahoo!
#
# 28) Yahoo!
#
# 29) Microsoft
#
# 30) Yahoo!
#
# 31) Microsoft
#
# 32) Apple
#
# 33) Yahoo!
#
# 34) Apple
#
# 35) Yahoo!
#
# 36) Google
#
# 37) Yahoo!
#
# 38) Facebook
#
# 39) Yahoo!
#
# 40) Google
#
# 41) Apple
#
# 42) Google
#
# 43

# %% [markdown]
# # 3. Prompt Template

# %%
from langchain_core.prompts import PromptTemplate

template = PromptTemplate.from_template(
    "Explain {topic} like I'm a beginner"
)

prompt = template.format(topic="Artificial Intelligence")
print(prompt)
print(llm_response(prompt))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Explain Artificial Intelligence like I'm a beginner
# Explain Artificial Intelligence like I'm a beginner and hope you'll find something interesting to learn.

# %% [markdown]
# # 4. Chains (Manual Chain Simulation)

# %%
def chain_run(topic):
    prompt = template.format(topic=topic)
    return llm_response(prompt)

print(chain_run("Machine Learning"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Explain Machine Learning like I'm a beginner.
#
# I'm gonna try to explain how I'm going to learn machine learning.
#
# 1) I'm going to teach a neural network for a machine learning machine.
#
# I'm going to teach a neural network for a machine learning machine.
#
# 2) I'm going to teach a neural network for a neural network for a machine learning machine.
#
# I'm going to teach a neural network for a neural network for a machine learning machine.
#
# 3) I'm going to show how an actor model will be modeled.
#
# I'm going to show how an actor model will be modeled.
#
# 4) I'm going to show how an actor model will be modeled.
#
# I'm going to show how an actor model will be modeled.
#
# 5) I'm going to show the state of a neural network.
#
# I'm going to show the state of a neural network.
#
# 6) I'm going to show how an actor model can compute an actor model.
#
# I'm going to show how an actor model can compute an actor model.
#
# 7) I'm going to show how a neural network can be modeled.
#
# I'm going to show how a neural network can be modeled.

# %% [markdown]
# #  5. Memory (Simple Simulation)

# %%
memory = []

def conversation(input_text):
    memory.append(input_text)
    context = " ".join(memory)
    return llm_response(context)

print(conversation("Hi, my name is Tejasri"))
print(conversation("What is my name?"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Hi, my name is Tejasri, I am the owner of this website. To be honest with you, I have no idea what you are talking about. For some reason, I am not allowed to host the website on my own server, and my webmaster does not want to host any of your articles on my site. So I have decided I will no longer host a website on my own server.
#
# I will do this if you ask me. If you would like to contribute a little money to this website, you can donate by clicking on the link below below. There will also be a small donation threshold and I will be able to help you out.
#
# Thank you for your support so far!
#
# –
#
# A few of the articles that I was discussing on this website are:
#
# Lily's Law on Sexual Orientation is a great resource for anyone who is looking for more on how sexuality and gender exist in women and how this can affect their life.
#
# I'll be making up some of the articles in this series in my own words.
#
# We're going to start with the basics:
#
# What is the difference between male and female?
#
# What is a gender identity?
#
# Why does this matter?
#
# What is gender,
# Hi, my name is Tejasri What is my name?
#
# Tesa has been a person who's been wanting to make some sort of change in my life - or at least to give my life a bit of a boost and to bring me through the world's darkest time.
#
# My name is Tejasri, and I'm going to be sharing this story with you all.
#
# I'm a 17-year-old girl and I've just been diagnosed with depression. I'm a 17-year-old girl and I've been diagnosed with depression.
#
# I'm not going anywhere. I'm just coming out, and I'm going to make this new life for myself.
#
# I think it's going to be a big change for me, and I'm going to be here to support me, to be here to support my family, to be here to support my friends and so many more.
#
# I am also going to be here to make this new life for myself and my family.
#
# I'm going to be here to make this new life for myself and my family, and then to give my life a boost.
#
# I'm going to be here to help you all.
#
# I'm going to be here to make this new life for myself and my family,

# %% [markdown]
# # 6. Document Loader

# %%
with open("data.txt", "w") as f:
    f.write("LangChain helps build LLM powered applications.")

with open("data.txt", "r") as f:
    documents = f.read()

print(documents)
# Out:
# LangChain helps build LLM powered applications.

# %% [markdown]
# #  7. Simple Retrieval

# %%
query = "What is LangChain?"

if "LangChain" in documents:
    print("Answer:", documents)
else:
    print("No relevant info found")
# Out:
# Answer: LangChain helps build LLM powered applications.

# %% [markdown]
# Conclusion
#
# In this notebook, we implemented key LangChain components such as prompt templates, chains, and memory to build modular LLM workflows.
#
# Although a local model was used instead of OpenAI due to API limitations, the overall architecture and concepts remain the same. This demonstrates how LangChain enables flexible and scalable AI application development.
